# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.isnull().sum()
#no missing data
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
sns.countplot(x=df["Churn"])
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.countplot(x='Partner', hue='Churn', data=df)
plt.title('Churn Distribution by Partner Status')
plt.xlabel('Partner')
plt.ylabel('Count')
plt.legend(title='Churn', loc='upper right')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Churn', y='MonthlyCharges', data=df)
plt.title('Monthly Charges by Churn Status')
plt.xlabel('Churn')
plt.ylabel('Monthly Charges')
plt.show()

# %%
plt.figure(figsize=(12, 8))
corr = df.select_dtypes(exclude="object").corr()
sns.heatmap(corr, annot=True,cmap='viridis', square=True, cbar=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
df["Churn"].value_counts()
# the ratio is too of this is an unbalance so need balancing
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
# text=["Partner","Dependents","PhoneService","PaperlessBilling","Churn"]

# %%
df=df.drop("customerID",axis=1)

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
for i in df.columns:
    print(i,df[i].unique())
# Out:
# gender ['Female' 'Male']
# SeniorCitizen [0 1]
# Partner ['Yes' 'No']
# Dependents ['No' 'Yes']
# tenure [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26  0
#  39]
# PhoneService ['No' 'Yes']
# MultipleLines ['No phone service' 'No' 'Yes']
# InternetService ['DSL' 'Fiber optic' 'No']
# OnlineSecurity ['No' 'Yes' 'No internet service']
# OnlineBackup ['Yes' 'No' 'No internet service']
# DeviceProtection ['No' 'Yes' 'No internet service']
# TechSupport ['No' 'Yes' 'No internet service']
# StreamingTV ['No' 'Yes' 'No internet service']
# StreamingMovies ['No' 'Yes' 'No internet service']
# Contract ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling ['Yes' 'No']
# PaymentMethod ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# ...

# %%
yes_no=["Partner","Dependents","PhoneService","PaperlessBilling","Churn"]

# %%
df["TotalCharges"]=pd.to_numeric(df["TotalCharges"],errors="coerce")
df.dropna(how="any",axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7032 non-null   object
#  1   SeniorCitizen     7032 non-null   int64
#  2   Partner           7032 non-null   object
#  3   Dependents        7032 non-null   object
#  4   tenure            7032 non-null   int64
#  5   PhoneService      7032 non-null   object
#  6   MultipleLines     7032 non-null   object
#  7   InternetService   7032 non-null   object
#  8   OnlineSecurity    7032 non-null   object
#  9   OnlineBackup      7032 non-null   object
#  10  DeviceProtection  7032 non-null   object
#  11  TechSupport       7032 non-null   object
#  12  StreamingTV       7032 non-null   object
#  13  StreamingMovies   7032 non-null   object
#  14  Contract          7032 non-null   object
#  15  PaperlessBilling  7032 non-null   object
# ...

# %%
for cols in df.columns:
    print(f"{cols} -> ",df[cols].unique())
# Out:
# gender ->  ['Female' 'Male']
# SeniorCitizen ->  [0 1]
# Partner ->  ['Yes' 'No']
# Dependents ->  ['No' 'Yes']
# tenure ->  [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService ->  ['No' 'Yes']
# MultipleLines ->  ['No phone service' 'No' 'Yes']
# InternetService ->  ['DSL' 'Fiber optic' 'No']
# OnlineSecurity ->  ['No' 'Yes' 'No internet service']
# OnlineBackup ->  ['Yes' 'No' 'No internet service']
# DeviceProtection ->  ['No' 'Yes' 'No internet service']
# TechSupport ->  ['No' 'Yes' 'No internet service']
# StreamingTV ->  ['No' 'Yes' 'No internet service']
# StreamingMovies ->  ['No' 'Yes' 'No internet service']
# Contract ->  ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling ->  ['Yes' 'No']
# PaymentMethod ->  ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
# ...

# %%
from sklearn.preprocessing import StandardScaler,OneHotEncoder,OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
import joblib

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     5163
# Yes    1869
# Name: count, dtype: int64

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
columns = [
    "gender",
    "MultipleLines",
    "InternetService",
    "OnlineSecurity",
    "OnlineBackup",
    "DeviceProtection",
    "TechSupport",
    "StreamingTV",
    "StreamingMovies",
    "Contract",
    "PaymentMethod",
    "Partner",
    "Dependents",
    "PhoneService",
    "PaperlessBilling"
]
#all catagorical columns
df["Churn"]=df["Churn"].map({"Yes": 1, "No": 0})

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
X=df.drop("Churn",axis=1)
Y=df[["Churn"]]

# %%
x_train, x_test, y_train ,y_test=train_test_split(X,Y,random_state=42,test_size=0.3)

# %%
pipe_line_catagorical=Pipeline(steps=[("imputing for safety",SimpleImputer(strategy="most_frequent")),
                                     ("converting catagorical to numeric",OneHotEncoder(sparse_output=False,handle_unknown="ignore"))])

# %%
# the pipeline is gonna be simple with an imputer for any data loss issue that went unnoticed and catagorical value converter since we have descition tree classifier no need for rescale

# %%
col_trans=ColumnTransformer(transformers=[("convert catagorical to numeric",pipe_line_catagorical,columns)],
                           remainder="passthrough",force_int_remainder_cols=False)

# %%
final_pipeline=make_pipeline(col_trans,DecisionTreeClassifier(criterion="gini",random_state=100,max_depth=6,min_samples_leaf=8))

# %%
final_pipeline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(force_int_remainder_cols=False,
#                                    remainder='passthrough',
#                                    transformers=[('convert catagorical to '
#                                                   'numeric',
#                                                   Pipeline(steps=[('imputing '
#                                                                    'for safety',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('converting '
#                                                                    'catagorical '
#                                                                    'to numeric',
#                                                                    OneHotEncoder(handle_unknown='ignore',
# ...

# %%
# our model is ready now save the pickle file

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
x_train
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 3946  Female              0      No         No       9           No
# 3394    Male              0      No         No      26          Yes
# 1635  Female              0      No         No       3          Yes
# 4088    Male              0      No         No       7          Yes
# 1886    Male              0     Yes        Yes      67          Yes
# ...      ...            ...     ...        ...     ...          ...
# 3778    Male              0      No         No       3          Yes
# 5199  Female              0      No         No      51          Yes
# 5235    Male              0      No         No       9          Yes
# 5399  Female              0      No         No      50          Yes
# 862     Male              1     Yes         No      20          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 3946  No phone service             DSL                  Yes
# ...

# %%
pd.DataFrame(final_pipeline.predict(x_test))
# Out:
#       0
# 0     0
# 1     0
# 2     1
# 3     0
# 4     0
# ...  ..
# 2105  0
# 2106  0
# 2107  0
# 2108  0
# 2109  0
#
# [2110 rows x 1 columns]

# %%
joblib.dump(final_pipeline,"model.joblib")
# Out:
# ['model.joblib']

# %%
final_pipeline.score(x_train,y_train)
# Out:
# 0.8149126371393742
